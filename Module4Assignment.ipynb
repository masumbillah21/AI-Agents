# %% [markdown]
# <a href="https://colab.research.google.com/github/masumbillah21/AI-Agents/blob/main/Module4Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve > output.log 2>&1 &
# !ollama pull phi4

# %%
# !pip install ollama faiss-cpu sentence-transformers numpy

# %% [markdown]
# Unoptimized Agent

# %%
import ollama
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
import time
import logging
from typing import List, Tuple

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class SimpleAgent:
    def __init__(self):
        self.embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
        self.dimension = 384  # Dimension of the embedding model
        self.index = faiss.IndexFlatL2(self.dimension)
        self.documents = []
        self.token_usage = 0
        self.query_times = []

    def embed_text(self, text: str) -> np.ndarray:
        """Generate embedding for a given text."""
        return self.embedding_model.encode([text])[0]

    def add_document(self, document: str):
        """Add a document to the FAISS index."""
        start_time = time.time()
        embedding = self.embed_text(document)
        self.index.add(np.array([embedding], dtype=np.float32))
        self.documents.append(document)
        logger.info(f"Added document. Time: {time.time() - start_time:.4f}s")

    def query(self, question: str, k: int = 1) -> Tuple[str, int]:
        """Query the agent with a question."""
        start_time = time.time()

        # Generate embedding for the question
        question_embedding = self.embed_text(question)

        # Search FAISS index
        distances, indices = self.index.search(np.array([question_embedding], dtype=np.float32), k)

        # Retrieve relevant documents
        context = [self.documents[idx] for idx in indices[0] if idx < len(self.documents)]
        context_text = "\n".join(context)

        # Prepare prompt (unoptimized: verbose and redundant)
        prompt = f"""
        You are a helpful assistant. Given the following context and question, provide a detailed answer.

        Context:
        {context_text}

        Question:
        {question}

        Please provide a comprehensive response with all relevant details.
        """

        # Call Ollama Phi-4
        response = ollama.chat(
            model='phi4',
            messages=[{'role': 'user', 'content': prompt}]
        )

        # Track token usage (approximate)
        prompt_tokens = len(prompt.split())
        response_tokens = len(response['message']['content'].split())
        total_tokens = prompt_tokens + response_tokens
        self.token_usage += total_tokens

        # Track query time
        query_time = time.time() - start_time
        self.query_times.append(query_time)

        logger.info(f"Query processed. Time: {query_time:.4f}s, Tokens: {total_tokens}")

        return response['message']['content'], total_tokens

    def get_performance_metrics(self) -> dict:
        """Return performance metrics."""
        return {
            'total_token_usage': self.token_usage,
            'average_query_time': np.mean(self.query_times) if self.query_times else 0,
            'number_of_queries': len(self.query_times)
        }

# Example usage
if __name__ == "__main__":
    agent = SimpleAgent()

    # Add sample documents
    documents = [
        "The capital of France is Paris.",
        "Python is a popular programming language.",
        "The sun is a star."
    ]

    for doc in documents:
        agent.add_document(doc)

    # Test queries
    queries = [
        "What is the capital of France?",
        "What is Python?",
        "Is the sun a star?"
    ]

    for query in queries:
        answer, tokens = agent.query(query)
        print(f"Query: {query}")
        print(f"Answer: {answer}")
        print(f"Tokens used: {tokens}\n")

    # Print performance metrics
    metrics = agent.get_performance_metrics()
    print("Performance Metrics:")
    print(f"Total Token Usage: {metrics['total_token_usage']}")
    print(f"Average Query Time: {metrics['average_query_time']:.4f}s")
    print(f"Number of Queries: {metrics['number_of_queries']}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Query: What is the capital of France?
# Answer: The capital of France is Paris. Located in the northern part of the country along the Seine River, Paris is not only the political and administrative center of France but also an influential cultural hub known worldwide for its art, fashion, gastronomy, and culture.
#
# ### Historical Context:
# Paris has a rich history that dates back to its founding by the Parisii tribe around 3rd century BC. It became one of the most important cities in medieval Europe during the reign of King Philip II in the late 12th century when he transformed it into a thriving metropolis. Throughout the centuries, it has been central to many significant historical events, including the French Revolution and both World Wars.
#
# ### Political Significance:
# As the capital city, Paris houses the official residences of the President of France (Élysée Palace), the Prime Minister (Hôtel Matignon), and the Parliament of France. It serves as a focal point for national governance and decision-making processes in France.
#
# ### Cultural Importance:
# Paris is renowned globally as a center for art and culture. It is home to iconic landmarks such as the Eiffel Tower, Notre-Dame Cathedral, and the Louvre Museum, which houses countless masterpieces including Leonardo da Vinci's "Mona Lisa." The city’s cultural influence extends into literature, music, fashion, and cuisine.
#
# ### Economic Role:
# Paris is a major global economic center. It hosts numerous multinational corporations’ headquarters, banks, and stock exchanges. Its economy spans industries from technology to luxury goods, making it a key player in international finance and commerce.
#
# ### Demographics and Lifestyle:
# With a population exceeding 2 million residents within its city limits, Paris forms part of the larger Île-de-France region that is home to over 12 million people. Known for its vibrant lifestyle, Paris offers an array of entertainment options such as theaters, museums, festivals, and restaurants.
#
# ### Tourism:
# Paris is one of the most visited cities in the world, attracting millions of tourists annually who come to explore its historical sites, experience its cultural offerings, and enjoy its renowned culinary scene. The city's charm lies not only in its famous attractions but also in its picturesque neighborhoods like Montmartre and Saint-Germain-des-Prés.
#
# In summary, Paris is more than just the capital city of France; it is a symbol of historical significance, political authority, cultural richness, economic strength, and an unparalleled lifestyle that continues to captivate people from all over the world.
# Tokens used: 433
#
# Query: What is Python?
# Answer: Python is a high-level, interpreted programming language known for its readability, simplicity, and versatility. Developed by Guido van Rossum in the late 1980s and first released in 1991, Python has become one of the most popular languages worldwide due to its ease of learning and broad applicability across various domains.
#
# ### Key Features of Python
#
# 1. **Readability and Simplicity**:
#    - Python emphasizes code readability with its use of significant whitespace and a syntax that allows programmers to express concepts in fewer lines of code compared to other languages like C++ or Java.
#    - The language uses English keywords frequently, which makes the code more intuitive.
#
# 2. **Interpreted Language**:
#    - Python is an interpreted language, meaning that it executes code line by line and does not require compilation into machine language before execution. This feature facilitates debugging and testing during development.
#
# 3. **Dynamic Typing**:
#    - In Python, variable types are determined at runtime, which allows for more flexibility but requires careful handling to avoid errors related to type mismatches.
#
# 4. **High-Level Data Structures**:
#    - Python provides built-in data structures such as lists, dictionaries, sets, and tuples that make it easy to manage collections of data efficiently.
#
# 5. **Extensive Standard Library**:
#    - The language comes with a comprehensive standard library that includes modules and functions for variable types, file operations, system calls, and even Internet protocols among others.
#
# 6. **Object-Oriented Programming (OOP)**:
#    - Python supports OOP paradigms, allowing developers to create reusable code through classes and objects.
#
# 7. **Functional Programming**:
#    - It also accommodates functional programming concepts like first-class functions, closures, and decorators.
#
# 8. **Scripting Language**:
#    - Python is widely used for scripting and automation tasks due to its straightforward syntax and powerful libraries.
#
# ### Applications of Python
#
# 1. **Web Development**:
#    - Frameworks such as Django and Flask make it easy to build robust web applications.
#
# 2. **Data Science and Machine Learning**:
#    - Libraries like NumPy, pandas, Matplotlib, scikit-learn, TensorFlow, and PyTorch are extensively used for data analysis, visualization, and machine learning tasks.
#
# 3. **Automation and Scripting**:
#    - Python’s simplicity makes it ideal for writing scripts to automate repetitive tasks across different platforms.
#
# 4. **Software Development**:
#    - It is used in the development of desktop GUI applications with libraries like Tkinter and PyQt.
#
# 5. **Network Programming**:
#    - Python supports various network protocols, making it suitable for developing networking software and tools.
#
# 6. **Scientific Computing**:
#    - Its performance and support for mathematical operations make it a choice for scientific research and computational simulations.
#
# 7. **Education**:
#    - Due to its straightforward syntax and readability, Python is often the first programming language taught in educational settings.
#
# ### Community and Ecosystem
#
# Python has a vibrant community that contributes to its extensive ecosystem of third-party packages available through the Python Package Index (PyPI). This active community ensures continuous improvement, support, and innovation within the language.
#
# ### Conclusion
#
# Python’s combination of simplicity, readability, and powerful features make it an ideal choice for both beginners learning programming and experienced developers working on complex projects. Its versatility across different fields and ease of use have cemented its place as a leading programming language in the tech industry.
# Tokens used: 552
#
# Query: Is the sun a star?
# Answer: Yes, the Sun is indeed a star. Here's a detailed explanation:
#
# ### Definition of a Star
#
# A star is a massive, luminous sphere of plasma held together by its own gravity. Stars are primarily composed of hydrogen and helium and generate energy through nuclear fusion processes in their cores.
#
# ### Characteristics of the Sun as a Star
#
# 1. **Composition**:
#    - The Sun is predominantly made up of hydrogen (about 74%) and helium (about 24%), with trace amounts of heavier elements such as oxygen, carbon, neon, and iron.
#
# 2. **Nuclear Fusion**:
#    - Like other stars, the Sun generates energy through nuclear fusion. In its core, hydrogen nuclei fuse to form helium, releasing a tremendous amount of energy in the process. This energy is emitted as light and heat.
#
# 3. **Life Cycle**:
#    - The Sun is currently in the main sequence phase of its life cycle, which is typical for stars. During this phase, it fuses hydrogen into helium steadily.
#    - It is estimated to be about 4.6 billion years old and is expected to remain in the main sequence for approximately another 5 billion years.
#
# 4. **Size and Mass**:
#    - The Sun's mass is about \(1.989 \times 10^{30}\) kilograms, which accounts for roughly 99.86% of the total mass of our solar system.
#    - It has a diameter of about 1.39 million kilometers (864,000 miles), making it the largest object in the solar system by far.
#
# 5. **Gravitational Influence**:
#    - The Sun's gravity governs the orbits of all objects within the solar system, including planets, asteroids, and comets. Its gravitational pull keeps these bodies in stable orbits around it.
#
# 6. **Luminosity**:
#    - The Sun emits energy at a rate of about \(3.8 \times 10^{26}\) watts. This luminosity is what provides light and warmth to Earth, making life possible here.
#
# 7. **Classification**:
#    - In terms of stellar classification, the Sun is categorized as a G-type main-sequence star (or G dwarf), often referred to as a "G2V" star. The "G" denotes its surface temperature and spectral characteristics, while "V" indicates that it is a main-sequence star.
#
# ### Conclusion
#
# In summary, the Sun fits all the criteria of what defines a star: it is a massive sphere of plasma, generates energy through nuclear fusion, and has sufficient mass to create a gravitational pull that keeps the solar system in order. As such, not only is the Sun classified as a star by astronomers, but its characteristics are representative of those found in many other stars throughout the universe.
# Tokens used: 449
#
# Performance Metrics:
# Total Token Usage: 1434
# Average Query Time: 50.4832s
# Number of Queries: 3

# %% [markdown]
# You Answer: Optimized Agent with performance metrics

# %% [markdown]
# Optimization Techniques Implemented:
# (List down the techniques you've used)
#
# *

# %%
#You need to write the agent here in this cell with optimization

# %% [markdown]
# Performance Improvement: (Comparision)
